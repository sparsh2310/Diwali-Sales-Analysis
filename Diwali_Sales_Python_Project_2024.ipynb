# %% [markdown]
# complete project on YouTube: https://www.youtube.com/@RishabhMishraOfficial
#
# complete project on GitHub: https://github.com/rishabhnmishra/Python_Diwali_Sales_Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import plotly.express as ps
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\spars\\Python\\Diwali Sales Data.csv")

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
# Drop null columns

# %%
df.drop(['Status','unnamed1'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
pd.isnull(df).sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (11239, 13)

# %%
# change Data Type
df['Amount']=df['Amount'].astype('int')

# %%
df["Amount"].dtype
# Out:
# dtype('int32')

# %%
# rename column
df.rename(columns={"Amount":"Total Amount"}).head(1)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
#
#          State     Zone  Occupation Product_Category  Orders  Total Amount
# 0  Maharashtra  Western  Healthcare             Auto       1         23952

# %%
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123900e+04  11239.000000    11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357        0.420055      2.489634   9453.610553
# std    1.716039e+03     12.753866        0.493589      1.114967   5222.355168
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
df[["Age","Amount"]].describe()
# Out:
#                 Age        Amount
# count  11239.000000  11239.000000
# mean      35.410357   9453.610553
# std       12.753866   5222.355168
# min       12.000000    188.000000
# 25%       27.000000   5443.000000
# 50%       33.000000   8109.000000
# 75%       43.000000  12675.000000
# max       92.000000  23952.000000

# %% [markdown]
# # Visualisation

# %%
c=["b","O"]
ax=sns.countplot(x="Gender",data=df)

# to show Data labels
for bars in ax.containers:
    ax.bar_label(bars)

# %%
df.groupby(["Gender"],as_index=False)["Amount"].sum().sort_values(by="Amount",ascending=False)
# Out:
#   Gender    Amount
# 0      F  74335853
# 1      M  31913276

# %%
df.groupby(["Gender"],as_index=False)["Amount"].sum().sort_values(by="Amount",ascending=False)
# Out:
#   Gender    Amount
# 0      F  74335853
# 1      M  31913276

# %%
# groupby()
sales_gen=df.groupby(["Gender"],as_index=False)["Amount"].sum().sort_values(by="Amount",ascending=False)
sns.barplot(x="Gender",y="Amount",data=sales_gen)
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
ax=sns.countplot(x="Age Group",data=df)

# to show Data labels
for bars in ax.containers:
    ax.bar_label(bars)

# %%
ax=sns.countplot(x="Age Group",data=df,hue="Gender")

# to show Data labels
for bars in ax.containers:
    ax.bar_label(bars)

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
sales_age=df.groupby(["Age Group"], as_index=False)["Amount"].sum().sort_values(by="Amount",ascending=False)
ax=sns.barplot(x="Age Group",y="Amount",data=sales_age)
for bars in ax.containers:
    ax.bar_label(bars,fmt="₹%.0f")
sns.set(rc={"figure.figsize":(20,8)})

# %%
sales_age=df.groupby(["Age Group"], as_index=False)["Amount"].sum().sort_values(by="Amount",ascending=False)
sns.barplot(x="Age Group",y="Amount",data=sales_age)
# Out:
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %% [markdown]
# # States

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
Sales_States=df.groupby(["State"],as_index=False)["Orders"].sum().sort_values(by="Orders",ascending=False).head(10)

sns.set(rc={"figure.figsize":(25,6)})
sns.barplot(x="State",y="Orders",data=Sales_States)
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %%
Sales_States=df.groupby(["State"],as_index=False)["Amount"].sum().sort_values(by="Amount",ascending=False).head(10)

sns.set(rc={"figure.figsize":(25,6)})
sns.barplot(x="State",y="Amount",data=Sales_States)
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %% [markdown]
# # Marital Status

# %%
mx=sns.countplot(data=df,x="Marital_Status")
sns.set(rc={"figure.figsize":(7,5)})
for bars in mx.containers:
    mx.bar_label(bars)

# %%
Martial=df.groupby(["Marital_Status","Gender"],as_index=False)["Amount"].sum().sort_values(by="Amount",ascending=False)
sns.set(rc={"figure.figsize":(6,5)})
sns.barplot(x="Marital_Status",y="Amount",data=Sales_States,hue="Gender")
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %% [markdown]
# # Occupation

# %%
sns.set(rc={"figure.figsize":(20,5)})
ox=sns.countplot(data=df,x="Occupation")

for bars in ox.containers:
    ox.bar_label(bars)

# %%
Ocpt=df.groupby(["Occupation"],as_index=False)["Amount"].sum().sort_values(by="Amount",ascending=False)
sns.barplot(x="Occupation",y="Amount",data=Ocpt)

# %%
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
sns.set(rc={"figure.figsize":(20,5)})
px=sns.countplot(data=df,x="Product_Category")

for bars in px.containers:
    px.bar_label(bars)

# %%
Pdt=df.groupby(["Product_Category"],as_index=False)["Amount"].sum().sort_values(by="Amount",ascending=False)
sns.barplot(x="Product_Category",y="Amount",data=Pdt)
sns.set(rc={"figure.figsize":(25,5)})

# %%
Pdt=df.groupby(["Product_Category"],as_index=False)["Amount"].sum().sort_values(by="Amount",ascending=False)
ax=sns.barplot(x="Product_Category",y="Amount",data=Pdt)
ax
# Out:
# <Axes: xlabel='Product_Category', ylabel='Amount'>
